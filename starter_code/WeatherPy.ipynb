# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Set units to metric
unit = "metric"

query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + unit

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities): 
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={unit}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zhuhai
# Processing Record 2 of Set 1 | westport
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | mehamn
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | alyangula
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | riyadh
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | portland
# Processing Record 18 of Set 1 | bongor
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | antofagasta
# Processing Record 22 of Set 1 | saldanha
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | kruisfontein
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | lewistown
# Processing Record 27 of Set 1 | talcahuano
# Processing Record 28 of Set 1 | hami
# Processing Record 29 of Set 1 | governador dix-sept rosado
# Processing Record 30 of Set 1 | algodones
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | pangnirtung
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | torbay
# Processing Record 39 of Set 1 | shieli
# Processing Record 40 of Set 1 | leningradskiy
# Processing Record 41 of Set 1 | kahului
# Processing Record 42 of Set 1 | eidfjord
# Processing Record 43 of Set 1 | oga
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | lyuban
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | ostrovnoy
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | laguna
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 0 of Set 2 | port hawkesbury
# Processing Record 1 of Set 2 | hakui
# Processing Record 2 of Set 2 | shurugwi
# Processing Record 3 of Set 2 | poum
# Processing Record 4 of Set 2 | mount gambier
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | visnes
# Processing Record 7 of Set 2 | chute-aux-outardes
# Processing Record 8 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | grafenau
# Processing Record 15 of Set 2 | codrington
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 2 | axim
# Processing Record 19 of Set 2 | auki
# Processing Record 20 of Set 2 | lata
# Processing Record 21 of Set 2 | bonavista
# Processing Record 22 of Set 2 | birao
# Processing Record 23 of Set 2 | kushmurun
# Processing Record 24 of Set 2 | mutoko
# Processing Record 25 of Set 2 | herat
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | awjilah
# Processing Record 28 of Set 2 | haines junction
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | geraldton
# Processing Record 31 of Set 2 | rahden
# Processing Record 32 of Set 2 | promyshlennyy
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | kavieng
# Processing Record 35 of Set 2 | kodiak
# Processing Record 36 of Set 2 | castro
# Processing Record 37 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 2 | porbandar
# Processing Record 39 of Set 2 | avanigadda
# Processing Record 40 of Set 2 | sydney
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | samarai
# Processing Record 46 of Set 2 | chara
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | cairns
# Processing Record 0 of Set 3 | manokwari
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | lavrentiya
# Processing Record 4 of Set 3 | tres arroyos
# Processing Record 5 of Set 3 | norman wells
# Processing Record 6 of Set 3 | marystown
# Processing Record 7 of Set 3 | okitipupa
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | oktyabrskoye
# Processing Record 10 of Set 3 | pevek
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | kalmunai
# Processing Record 13 of Set 3 | qaanaaq
# Processing Record 14 of Set 3 | san patricio
# Processing Record 15 of Set 3 | emerald
# Processing Record 16 of Set 3 | log
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 3 | shalinskoye
# Processing Record 20 of Set 3 | ozernovskiy
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 3 | orgun
# City not found. Skipping...
# Processing Record 24 of Set 3 | albany
# Processing Record 25 of Set 3 | puerto cabezas
# Processing Record 26 of Set 3 | tigil
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | marawi
# Processing Record 29 of Set 3 | melipilla
# Processing Record 30 of Set 3 | ghanzi
# Processing Record 31 of Set 3 | santa vitoria
# Processing Record 32 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 3 | blagoyevo
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | paamiut
# Processing Record 36 of Set 3 | barzas
# Processing Record 37 of Set 3 | tuktoyaktuk
# Processing Record 38 of Set 3 | karoi
# Processing Record 39 of Set 3 | east london
# Processing Record 40 of Set 3 | tiznit
# Processing Record 41 of Set 3 | port elizabeth
# Processing Record 42 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 3 | lighthouse point
# Processing Record 44 of Set 3 | cape town
# Processing Record 45 of Set 3 | sinnamary
# Processing Record 46 of Set 3 | vila velha
# Processing Record 47 of Set 3 | barras
# Processing Record 48 of Set 3 | ribeira grande
# Processing Record 49 of Set 3 | sao joao da barra
# Processing Record 0 of Set 4 | ponta delgada
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | myre
# Processing Record 3 of Set 4 | brae
# Processing Record 4 of Set 4 | partizanske
# Processing Record 5 of Set 4 | sucre
# Processing Record 6 of Set 4 | kavaratti
# Processing Record 7 of Set 4 | nanortalik
# Processing Record 8 of Set 4 | klaksvik
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | verkh-usugli
# Processing Record 11 of Set 4 | kaeo
# Processing Record 12 of Set 4 | maldonado
# Processing Record 13 of Set 4 | bogande
# Processing Record 14 of Set 4 | miri
# Processing Record 15 of Set 4 | acapulco
# Processing Record 16 of Set 4 | loreto
# Processing Record 17 of Set 4 | ust-ishim
# Processing Record 18 of Set 4 | kaihua
# Processing Record 19 of Set 4 | neubrandenburg
# Processing Record 20 of Set 4 | ganzhou
# Processing Record 21 of Set 4 | kedrovyy
# Processing Record 22 of Set 4 | hervey bay
# Processing Record 23 of Set 4 | kapaa
# Processing Record 24 of Set 4 | ponta do sol
# Processing Record 25 of Set 4 | yayva
# Processing Record 26 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 4 | novovasylivka
# Processing Record 28 of Set 4 | los llanos de aridane
# Processing Record 29 of Set 4 | litovko
# Processing Record 30 of Set 4 | jedrzejow
# Processing Record 31 of Set 4 | bubaque
# Processing Record 32 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 4 | okahandja
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | longyearbyen
# Processing Record 36 of Set 4 | mastic beach
# Processing Record 37 of Set 4 | tabou
# Processing Record 38 of Set 4 | namibe
# Processing Record 39 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 4 | pochutla
# Processing Record 41 of Set 4 | contamana
# Processing Record 42 of Set 4 | torres
# Processing Record 43 of Set 4 | hamilton
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | belaya gora
# Processing Record 46 of Set 4 | nabire
# Processing Record 47 of Set 4 | batagay-alyta
# Processing Record 48 of Set 4 | ahipara
# Processing Record 49 of Set 4 | kushima
# Processing Record 0 of Set 5 | khatanga
# Processing Record 1 of Set 5 | anshun
# Processing Record 2 of Set 5 | panguna
# Processing Record 3 of Set 5 | neiafu
# Processing Record 4 of Set 5 | moranbah
# Processing Record 5 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 5 | rovaniemi
# Processing Record 7 of Set 5 | kifri
# Processing Record 8 of Set 5 | ongandjera
# Processing Record 9 of Set 5 | bastia
# Processing Record 10 of Set 5 | road town
# Processing Record 11 of Set 5 | okha
# Processing Record 12 of Set 5 | esmeraldas
# Processing Record 13 of Set 5 | elko
# Processing Record 14 of Set 5 | carnarvon
# Processing Record 15 of Set 5 | motupe
# Processing Record 16 of Set 5 | gazojak
# Processing Record 17 of Set 5 | nome
# Processing Record 18 of Set 5 | sokoto
# Processing Record 19 of Set 5 | dukat
# Processing Record 20 of Set 5 | sembe
# Processing Record 21 of Set 5 | ileza
# Processing Record 22 of Set 5 | dinard
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | skjervoy
# Processing Record 25 of Set 5 | cockburn town
# Processing Record 26 of Set 5 | tura
# Processing Record 27 of Set 5 | visby
# Processing Record 28 of Set 5 | mabaruma
# Processing Record 29 of Set 5 | strezhevoy
# Processing Record 30 of Set 5 | cedar city
# Processing Record 31 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 5 | arman
# Processing Record 33 of Set 5 | iqaluit
# Processing Record 34 of Set 5 | buchanan
# Processing Record 35 of Set 5 | varnamo
# Processing Record 36 of Set 5 | vardo
# Processing Record 37 of Set 5 | katobu
# Processing Record 38 of Set 5 | souillac
# Processing Record 39 of Set 5 | redmond
# Processing Record 40 of Set 5 | bogale
# Processing Record 41 of Set 5 | shelburne
# Processing Record 42 of Set 5 | ibra
# Processing Record 43 of Set 5 | egvekinot
# Processing Record 44 of Set 5 | santa rosa
# Processing Record 45 of Set 5 | bethel
# Processing Record 46 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 5 | lazaro cardenas
# Processing Record 48 of Set 5 | adre
# Processing Record 49 of Set 5 | mazulskiy
# City not found. Skipping...
# Processing Record 0 of Set 6 | camacha
# Processing Record 1 of Set 6 | zhigansk
# Processing Record 2 of Set 6 | sur
# Processing Record 3 of Set 6 | coahuayana
# Processing Record 4 of Set 6 | kota belud
# Processing Record 5 of Set 6 | monrovia
# Processing Record 6 of Set 6 | qui nhon
# Processing Record 7 of Set 6 | asau
# Processing Record 8 of Set 6 | beloha
# Processing Record 9 of Set 6 | fortuna
# Processing Record 10 of Set 6 | turukhansk
# Processing Record 11 of Set 6 | itacoatiara
# Processing Record 12 of Set 6 | sioux lookout
# Processing Record 13 of Set 6 | setermoen
# Processing Record 14 of Set 6 | mackay
# Processing Record 15 of Set 6 | peikang
# City not found. Skipping...
# Processing Record 16 of Set 6 | rawson
# Processing Record 17 of Set 6 | prince rupert
# Processing Record 18 of Set 6 | baghdad
# Processing Record 19 of Set 6 | usogorsk
# Processing Record 20 of Set 6 | malmyzh
# Processing Record 21 of Set 6 | rock sound
# Processing Record 22 of Set 6 | katsuura
# Processing Record 23 of Set 6 | karratha
# Processing Record 24 of Set 6 | rauma
# Processing Record 25 of Set 6 | khislavichi
# Processing Record 26 of Set 6 | liman
# Processing Record 27 of Set 6 | bengkulu
# Processing Record 28 of Set 6 | kawalu
# Processing Record 29 of Set 6 | bermeo
# Processing Record 30 of Set 6 | bocaranga
# City not found. Skipping...
# Processing Record 31 of Set 6 | polunochnoye
# Processing Record 32 of Set 6 | bosaso
# Processing Record 33 of Set 6 | dobronin
# Processing Record 34 of Set 6 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 35 of Set 6 | bengbu
# Processing Record 36 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 6 | tambura
# Processing Record 38 of Set 6 | atar
# Processing Record 39 of Set 6 | oktyabrskiy
# Processing Record 40 of Set 6 | margate
# Processing Record 41 of Set 6 | talnakh
# Processing Record 42 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 6 | grand gaube
# Processing Record 44 of Set 6 | coihaique
# Processing Record 45 of Set 6 | san cristobal
# Processing Record 46 of Set 6 | mitsamiouli
# Processing Record 47 of Set 6 | necochea
# Processing Record 48 of Set 6 | sterling
# Processing Record 49 of Set 6 | poya
# Processing Record 0 of Set 7 | vanavara
# Processing Record 1 of Set 7 | bemidji
# Processing Record 2 of Set 7 | kutum
# Processing Record 3 of Set 7 | rosarito
# Processing Record 4 of Set 7 | seguin
# Processing Record 5 of Set 7 | suluq
# Processing Record 6 of Set 7 | hurghada
# Processing Record 7 of Set 7 | matipo
# Processing Record 8 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 7 | tongliao
# Processing Record 10 of Set 7 | praia da vitoria
# Processing Record 11 of Set 7 | lasa
# Processing Record 12 of Set 7 | gulariya
# Processing Record 13 of Set 7 | quatre cocos
# Processing Record 14 of Set 7 | santa cruz del sur
# Processing Record 15 of Set 7 | roald
# Processing Record 16 of Set 7 | biak
# Processing Record 17 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 18 of Set 7 | faanui
# Processing Record 19 of Set 7 | buala
# Processing Record 20 of Set 7 | springdale
# Processing Record 21 of Set 7 | havelock
# Processing Record 22 of Set 7 | jyvaskyla
# Processing Record 23 of Set 7 | lodingen
# Processing Record 24 of Set 7 | pechenga
# Processing Record 25 of Set 7 | vila franca do campo
# Processing Record 26 of Set 7 | tuatapere
# Processing Record 27 of Set 7 | loveland
# Processing Record 28 of Set 7 | richard toll
# City not found. Skipping...
# Processing Record 29 of Set 7 | port antonio
# Processing Record 30 of Set 7 | kupino
# Processing Record 31 of Set 7 | san jeronimo
# Processing Record 32 of Set 7 | mbandaka
# Processing Record 33 of Set 7 | tual
# Processing Record 34 of Set 7 | sitka
# Processing Record 35 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 36 of Set 7 | weatherford
# Processing Record 37 of Set 7 | bahia de caraquez
# Processing Record 38 of Set 7 | fairview
# Processing Record 39 of Set 7 | speightstown
# Processing Record 40 of Set 7 | kamenka
# Processing Record 41 of Set 7 | mangrol
# Processing Record 42 of Set 7 | sofiysk
# City not found. Skipping...
# Processing Record 43 of Set 7 | bathsheba
# Processing Record 44 of Set 7 | yangambi
# Processing Record 45 of Set 7 | port blair
# Processing Record 46 of Set 7 | floriano
# Processing Record 47 of Set 7 | sola
# Processing Record 48 of Set 7 | lorengau
# Processing Record 49 of Set 7 | port hardy
# Processing Record 0 of Set 8 | luderitz
# Processing Record 1 of Set 8 | spassk
# Processing Record 2 of Set 8 | kargil
# Processing Record 3 of Set 8 | havre-saint-pierre
# Processing Record 4 of Set 8 | wilmington
# Processing Record 5 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 6 of Set 8 | pasinler
# Processing Record 7 of Set 8 | pleasanton
# Processing Record 8 of Set 8 | kilinochchi
# Processing Record 9 of Set 8 | erzin
# Processing Record 10 of Set 8 | elmira
# Processing Record 11 of Set 8 | constitucion
# Processing Record 12 of Set 8 | pop
# Processing Record 13 of Set 8 | santa cruz cabralia
# Processing Record 14 of Set 8 | beringovskiy
# Processing Record 15 of Set 8 | praya
# Processing Record 16 of Set 8 | sabha
# Processing Record 17 of Set 8 | xining
# Processing Record 18 of Set 8 | kirakira
# Processing Record 19 of Set 8 | mukacheve
# Processing Record 20 of Set 8 | berlevag
# Processing Record 21 of Set 8 | charters towers
# Processing Record 22 of Set 8 | teguldet
# Processing Record 23 of Set 8 | bindura
# Processing Record 24 of Set 8 | kuju
# Processing Record 25 of Set 8 | galveston
# Processing Record 26 of Set 8 | namatanai
# Processing Record 27 of Set 8 | gigmoto
# Processing Record 28 of Set 8 | chapais
# Processing Record 29 of Set 8 | esperance
# Processing Record 30 of Set 8 | khudumelapye
# Processing Record 31 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 32 of Set 8 | finschhafen
# Processing Record 33 of Set 8 | san juan de abajo
# Processing Record 34 of Set 8 | pringsewu
# Processing Record 35 of Set 8 | hualmay
# Processing Record 36 of Set 8 | saskylakh
# Processing Record 37 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 38 of Set 8 | thinadhoo
# Processing Record 39 of Set 8 | itaguacu
# Processing Record 40 of Set 8 | christchurch
# Processing Record 41 of Set 8 | ancud
# Processing Record 42 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 8 | gizo
# Processing Record 44 of Set 8 | nata
# Processing Record 45 of Set 8 | sept-iles
# Processing Record 46 of Set 8 | kamina
# Processing Record 47 of Set 8 | fairbanks
# Processing Record 48 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 8 | kiruna
# Processing Record 0 of Set 9 | fort nelson
# Processing Record 1 of Set 9 | najran
# Processing Record 2 of Set 9 | barbastro
# Processing Record 3 of Set 9 | dakar
# Processing Record 4 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 9 | bilibino
# Processing Record 6 of Set 9 | williston
# Processing Record 7 of Set 9 | athabasca
# Processing Record 8 of Set 9 | el cope
# Processing Record 9 of Set 9 | reinosa
# Processing Record 10 of Set 9 | pavlodar
# Processing Record 11 of Set 9 | dawson
# Processing Record 12 of Set 9 | chuy
# Processing Record 13 of Set 9 | severo-kurilsk
# Processing Record 14 of Set 9 | palmer
# Processing Record 15 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 9 | sobolevo
# Processing Record 17 of Set 9 | lagoa
# Processing Record 18 of Set 9 | jijiga
# Processing Record 19 of Set 9 | waipawa
# Processing Record 20 of Set 9 | port hedland
# Processing Record 21 of Set 9 | pisco
# Processing Record 22 of Set 9 | kangaatsiaq
# Processing Record 23 of Set 9 | cabo san lucas
# Processing Record 24 of Set 9 | dunmore east
# Processing Record 25 of Set 9 | lahij
# Processing Record 26 of Set 9 | mgandu
# Processing Record 27 of Set 9 | cayeli
# Processing Record 28 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 9 | gwanda
# Processing Record 30 of Set 9 | sairang
# Processing Record 31 of Set 9 | nelson bay
# Processing Record 32 of Set 9 | taoudenni
# Processing Record 33 of Set 9 | masuguru
# Processing Record 34 of Set 9 | puerto rondon
# Processing Record 35 of Set 9 | sao filipe
# Processing Record 36 of Set 9 | majene
# Processing Record 37 of Set 9 | dunedin
# Processing Record 38 of Set 9 | provideniya
# Processing Record 39 of Set 9 | magdagachi
# Processing Record 40 of Set 9 | grand-santi
# Processing Record 41 of Set 9 | santona
# Processing Record 42 of Set 9 | manbij
# Processing Record 43 of Set 9 | caravelas
# Processing Record 44 of Set 9 | odugathur
# City not found. Skipping...
# Processing Record 45 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 9 | nakambala
# Processing Record 47 of Set 9 | roma
# Processing Record 48 of Set 9 | tartagal
# Processing Record 49 of Set 9 | bajil
# Processing Record 0 of Set 10 | novobirilyussy
# Processing Record 1 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 2 of Set 10 | kaseda
# Processing Record 3 of Set 10 | smirnykh
# Processing Record 4 of Set 10 | magadan
# Processing Record 5 of Set 10 | farsund
# Processing Record 6 of Set 10 | bulawayo
# Processing Record 7 of Set 10 | pilar
# Processing Record 8 of Set 10 | baykalsk
# Processing Record 9 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 10 | plettenberg bay
# Processing Record 11 of Set 10 | nushki
# Processing Record 12 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 10 | fort morgan
# Processing Record 14 of Set 10 | meulaboh
# Processing Record 15 of Set 10 | komsomolskiy
# Processing Record 16 of Set 10 | dwarka
# Processing Record 17 of Set 10 | bagdarin
# Processing Record 18 of Set 10 | genhe
# Processing Record 19 of Set 10 | hailar
# Processing Record 20 of Set 10 | itacarambi
# Processing Record 21 of Set 10 | vetas
# Processing Record 22 of Set 10 | faya
# Processing Record 23 of Set 10 | jardim do serido
# Processing Record 24 of Set 10 | kilis
# Processing Record 25 of Set 10 | moose factory
# Processing Record 26 of Set 10 | port macquarie
# Processing Record 27 of Set 10 | mackenzie
# Processing Record 28 of Set 10 | waingapu
# Processing Record 29 of Set 10 | nalgonda
# Processing Record 30 of Set 10 | montrose
# Processing Record 31 of Set 10 | northam
# Processing Record 32 of Set 10 | bandarbeyla
# Processing Record 33 of Set 10 | kotri
# Processing Record 34 of Set 10 | avera
# Processing Record 35 of Set 10 | ugoofaaru
# Processing Record 36 of Set 10 | praia
# Processing Record 37 of Set 10 | ixtapa
# Processing Record 38 of Set 10 | varadero
# Processing Record 39 of Set 10 | tazovskiy
# Processing Record 40 of Set 10 | boulder
# Processing Record 41 of Set 10 | rocha
# Processing Record 42 of Set 10 | chenghai
# Processing Record 43 of Set 10 | gambiran
# Processing Record 44 of Set 10 | matara
# Processing Record 45 of Set 10 | aras
# Processing Record 46 of Set 10 | cervo
# Processing Record 47 of Set 10 | atikokan
# Processing Record 48 of Set 10 | bambanglipuro
# Processing Record 49 of Set 10 | popondetta
# Processing Record 0 of Set 11 | belmonte
# Processing Record 1 of Set 11 | zhashkiv
# Processing Record 2 of Set 11 | yar-sale
# Processing Record 3 of Set 11 | srednekolymsk
# Processing Record 4 of Set 11 | terra santa
# Processing Record 5 of Set 11 | zatoka
# Processing Record 6 of Set 11 | urengoy
# Processing Record 7 of Set 11 | grindavik
# Processing Record 8 of Set 11 | kampot
# Processing Record 9 of Set 11 | saint george
# Processing Record 10 of Set 11 | akureyri
# Processing Record 11 of Set 11 | sao jose da coroa grande
# Processing Record 12 of Set 11 | cardenas
# Processing Record 13 of Set 11 | mocuba
# Processing Record 14 of Set 11 | shanghai
# Processing Record 15 of Set 11 | san buenaventura
# Processing Record 16 of Set 11 | santa isabel
# Processing Record 17 of Set 11 | gladstone
# Processing Record 18 of Set 11 | hefei
# Processing Record 19 of Set 11 | galle
# Processing Record 20 of Set 11 | kristiinankaupunki
# Processing Record 21 of Set 11 | noumea
# Processing Record 22 of Set 11 | asuncion
# Processing Record 23 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 11 | songea
# Processing Record 25 of Set 11 | wahiawa
# Processing Record 26 of Set 11 | gaoua
# Processing Record 27 of Set 11 | selikhino
# Processing Record 28 of Set 11 | soanierana ivongo
# Processing Record 29 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 30 of Set 11 | along
# Processing Record 31 of Set 11 | grenville
# Processing Record 32 of Set 11 | ust-kuyga
# Processing Record 33 of Set 11 | las choapas
# Processing Record 34 of Set 11 | goalpara
# Processing Record 35 of Set 11 | batagay
# Processing Record 36 of Set 11 | ramhormoz
# Processing Record 37 of Set 11 | pinczow
# Processing Record 38 of Set 11 | dingzhou
# Processing Record 39 of Set 11 | manzil salim
# Processing Record 40 of Set 11 | imeni poliny osipenko
# Processing Record 41 of Set 11 | pathein
# Processing Record 42 of Set 11 | nishihara
# Processing Record 43 of Set 11 | coolum beach
# Processing Record 44 of Set 11 | yerbogachen
# Processing Record 45 of Set 11 | shingu
# Processing Record 46 of Set 11 | edd
# Processing Record 47 of Set 11 | sorong
# Processing Record 48 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 11 | madang
# Processing Record 0 of Set 12 | greencastle
# Processing Record 1 of Set 12 | sale
# Processing Record 2 of Set 12 | bud
# Processing Record 3 of Set 12 | stanovoye
# Processing Record 4 of Set 12 | neunkirchen
# Processing Record 5 of Set 12 | sabang
# Processing Record 6 of Set 12 | jalingo
# Processing Record 7 of Set 12 | orlik
# Processing Record 8 of Set 12 | lixourion
# Processing Record 9 of Set 12 | tessalit
# Processing Record 10 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 12 | manacapuru
# Processing Record 12 of Set 12 | uman
# Processing Record 13 of Set 12 | aklavik
# Processing Record 14 of Set 12 | liverpool
# Processing Record 15 of Set 12 | comodoro rivadavia
# Processing Record 16 of Set 12 | terenos
# Processing Record 17 of Set 12 | okhotsk
# Processing Record 18 of Set 12 | hoi an
# Processing Record 19 of Set 12 | bavly
# Processing Record 20 of Set 12 | kudahuvadhoo
# Processing Record 21 of Set 12 | north bend
# Processing Record 22 of Set 12 | muscat
# Processing Record 23 of Set 12 | karasjok
# Processing Record 24 of Set 12 | novikovo
# Processing Record 25 of Set 12 | fereydunshahr
# Processing Record 26 of Set 12 | la huaca
# Processing Record 27 of Set 12 | pomichna
# Processing Record 28 of Set 12 | barranca
# Processing Record 29 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 30 of Set 12 | francisco beltrao
# Processing Record 31 of Set 12 | whitehorse
# Processing Record 32 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 12 | dubove
# Processing Record 34 of Set 12 | amelia
# Processing Record 35 of Set 12 | sidi qasim
# City not found. Skipping...
# Processing Record 36 of Set 12 | bergen
# Processing Record 37 of Set 12 | canaries
# Processing Record 38 of Set 12 | ajdabiya
# Processing Record 39 of Set 12 | andenes
# Processing Record 40 of Set 12 | kodinsk
# Processing Record 41 of Set 12 | dingle
# Processing Record 42 of Set 12 | yatou
# Processing Record 43 of Set 12 | pitea
# Processing Record 44 of Set 12 | jieshi
# Processing Record 45 of Set 12 | ulaanbaatar
# Processing Record 46 of Set 12 | huilong
# Processing Record 47 of Set 12 | gao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature


# Incorporate the other graph properties


# Save the figure


# Show plot

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity



# Incorporate the other graph properties


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
